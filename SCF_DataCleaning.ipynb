# %% [markdown]
# <a href="https://colab.research.google.com/github/LouisYLWang/SCF-2-SN/blob/main/SCF_DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# To check R version
R.version.string
# Out:
# [1] "R version 4.2.0 (2022-04-22)"

# %% [markdown]
# #**Installing packages and libraries**

# %%
#install packages and load libraries
library(dplyr)
library(readxl)
install.packages("xlsx", INSTALL_opts=c("--no-multiarch")) #install package xlsx this way to be compatible w/ 64-bit Java only
library(xlsx)
# install.packages("tidyr")
library(tidyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘rJava’, ‘xlsxjars’

# %% [markdown]
# **Requirements:**
#
# **1.   “SCF 2021.3” sheet**
#
#
# *   SCF Domain: 32 total domains in string format, full list sees “SCF Domains & Principles” sheet
# *   SCF Control: name of each control in string format
# *   SCF #: ID of each control in string format
# *   Control Description: Long string, when importing, should be concatenated with “Method To Comply With SCF Controls” and “SCF Control Question”
# *   Method To Comply With SCF Controls: Long string
# *   SCF Control Question: Long string
# *   Function Grouping: 5 total function groups in string format
# *   Regulation and chapter ID: columns after columns R to IQ provide information about how SCF controls map to each framework and regulation. Value in each cell stands for the related chapters of control in each row.
#
# **2.   “Authoritative Sources” sheet:**
# *   Version: string
# *   URL: string
#
#
#
#
# ---
#
#
#
#
# **Cleaning Tasks**
#
# 1. Drop unnessary columns (for both sheets) and check column names: Done
# 2. Check the column datatypes to match above requirements (in R, chr is equivalent to string format) -- use is.character and as.character: Done
# 3. Concatenate: "Secure Controls Framework (SCF) Control Description", “Method To Comply With SCF Controls”, and “SCF Control Question” columns: Done
# 4. Concatenate SCF Number (#) and SCF Control columns for the column Name in Control Objective target table: Done
# 5. Remove duplicates from Authoritative Source and Version columns in Authoritative Sources sheet: Done
# 6. Map multiple chapter IDs (Citations) correctly to the column Name in Control Objective target table (or SCF # and SCF Control columns in source data)
# 7. Export both sheets into CSV/JDBC/XML (choose CSV)
# 8. Relationship between target tables: Each Authority Document contains one or multiple Citations, each of which in turn contains a Control Objective that defines a risk category: Done
# 9. For the citation table, split multiple values in the column in multiple rows

# %% [markdown]
# #**Cleaning SCF 2021.3 sheet**

# %%
# Importing scf sheet (2021 Version)
# scf = read_excel("/content/Secure Controls Framework (SCF) - 2021.3.xlsx")

#Importing scf sheet (Anh's version)
scf = read_excel("/content/SCF-2021_3 raw data.xlsx")

# Checking first few rows of scf sheet
head(scf, n=1)

# Checking last few rows of scf sheet
tail(scf, n=1)

# Check dimensions
dim(scf)
# Out:
#   SCF Domain                    SCF Control                           SCF #
# 1 Security & Privacy Governance Security & Privacy Governance Program GOV-01
#   Secure Controls Framework (SCF)\r\nControl Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Relative Control\r\nWeighting\r\n(1-10) Function Grouping
# 1 10                                      Identify
#   SCRM\r\nTier 1\r\nStrategic SCRM\r\nTier 2\r\nOperational ⋯ Threat\r\nMT-4
# 1 X                           X                             ⋯ NA
#   Threat\r\nMT-5 Threat\r\nMT-6 Threat\r\nMT-7 Threat\r\nMT-8 Threat\r\nMT-9
# 1 NA             NA             MT-7           MT-8           MT-9
#   Threat\r\nMT-10 SCF Errata\r\n2021.1 SCF Errata\r\n2021.2
# 1 NA              ISO 27001 6.1.1      NA
#   SCF Errata\r\n2021.3
# 1 - ISO 27001 added 4.3 & 4.4
#   SCF Domain   SCF Control          SCF #
# 1 Web Security Web Browser Security WEB-12
#   Secure Controls Framework (SCF)\r\nControl Description
# 1 Mechanisms exist to ensure web applications implement Content-Security-Policy, HSTS and X-Frame-Options response headers to protect both the web application and its users.
#   Methods To Comply With SCF Controls
# 1 NA
#   SCF Control Question
# 1 Does the organization ensure web applications implement Content-Security-Policy, HSTS and X-Frame-Options response headers to protect both the web application and its users?
#   Relative Control\r\nWeighting\r\n(1-10) Function Grouping
# 1 9                                       Protect
#   SCRM\r\nTier 1\r\nStrategic SCRM\r\nTier 2\r\nOperational ⋯ Threat\r\nMT-4
# 1 NA                          X                             ⋯ NA
#   Threat\r\nMT-5 Threat\r\nMT-6 Threat\r\nMT-7 Threat\r\nMT-8 Threat\r\nMT-9
# 1 NA             NA             MT-7           MT-8           MT-9
#   Threat\r\nMT-10 SCF Errata\r\n2021.1 SCF Errata\r\n2021.2
# 1 NA              New addition         NA
#   SCF Errata\r\n2021.3
# 1 NA
# [1] 1006  251

# %%
# Check missing values
colSums(is.na(scf))

# Drop unnecesary columns from scf sheet
drop <- c("Relative Control\r\nWeighting\r\n(1-10)", "SCRM\r\nTier 1\r\nStrategic", "SCRM\r\nTier 2\r\nOperational", "SCRM\r\nTier 3\r\nTactical",
          "SP-CMM 0\r\nNot Performed", "SP-CMM 1\r\nPerformed Informally", "SP-CMM 2\r\nPlanned & Tracked", "SP-CMM 3\r\nWell Defined", 
          "SP-CMM 4\r\nQuantitatively Controlled", "SP-CMM 5\r\nContinuously Improving")
scf = scf[,!(names(scf) %in% drop)]

# Check df dimensions after dropping
dim(scf)

# Check datatypes of all columns again to make sure they match specs doc
glimpse(scf)
# Out:
#                                             SCF Domain
#                                                      0
#                                            SCF Control
#                                                      0
#                                                  SCF #
#                                                      0
# Secure Controls Framework (SCF)\r\nControl Description
#                                                      0
#                    Methods To Comply With SCF Controls
#                                                    602
#                                   SCF Control Question
#                                                      0
#                Relative Control\r\nWeighting\r\n(1-10)
#                                                      0
#                                      Function Grouping
#                                                      0
#                            SCRM\r\nTier 1\r\nStrategic
#                                                    847
#                          SCRM\r\nTier 2\r\nOperational
#                                                    213
#                             SCRM\r\nTier 3\r\nTactical
#                                                    314
#                              SP-CMM 0\r\nNot Performed
#                                                      0
#                       SP-CMM 1\r\nPerformed Informally
#                                                      0
#                          SP-CMM 2\r\nPlanned & Tracked
#                                                      0
#                               SP-CMM 3\r\nWell Defined
#                                                      0
#                  SP-CMM 4\r\nQuantitatively Controlled
#                                                      0
#                     SP-CMM 5\r\nContinuously Improving
#                                                      0
#                           AICPA\r\nTSC 2017\r\n(SOC 2)
#                                                    723
#                                     CIS\r\nCSC\r\nv7.1
#                                                    817
#                                     CIS\r\nCSC\r\nv8.0
#                                                    799
#                                          COBIT\r\n2019
#                                                    857
#                                          COSO\r\nv2017
#                                                    981
#                                   CSA\r\nCCM\r\nv3.0.1
#                                                    892
#                                       CSA\r\nCCM\r\nv4
#                                                    673
#                                   CSA\r\nIoT SCF\r\nv2
#                                                    745
#                                          ENISA\r\nv2.0
#                                                    945
#                                                   GAPP
#                                                    957
#                                          IEC 62443-4-2
#                                                    880
#                                  ISO\r\n22301\r\nv2019
#                                                    975
#                                  ISO\r\n27001\r\nv2013
#                                                    961
#                                  ISO\r\n27002\r\nv2013
#                                                    819
#                                 ISO \r\n27018\r\nv2014
#                                                    989
#                                 ISO\r\n27701 \r\nv2019
#                                                    812
#                                  ISO\r\n29100\r\nv2011
#                                                    973
#                                  ISO\r\n31000\r\nv2009
#                                                    988
#                                  ISO\r\n31010\r\nv2009
#                                                    977
#              MPA \r\nContent Security Program\r\nv4.07
#                                                    767
#    NIAC\r\nInsurance Data Security Model Law (MDL-668)
#                                                    929
#                         NIST Privacy Framework\r\nv1.0
#                                                    820
#                                           NIST\r\nSSDF
#                                                    963
#                               NIST\r\n800-37 \r\nrev 2
#                                                    969
#                                         NIST\r\n800-39
#                                                    985
#                                 NIST\r\n800-53\r\nrev4
#                                                    379
#                           NIST\r\n800-53 rev4\r\n[low]
#                                                    857
#                      NIST\r\n800-53 rev4\r\n[moderate]
#                                                    723
#                          NIST\r\n800-53 rev4\r\n[high]
#                                                    649
#                                 NIST\r\n800-53\r\nrev5
#                                                    267
#                    NIST\r\n800-53\r\nrev5\r\n[privacy]
#                                                    892
#                        NIST\r\n800-53\r\nrev5\r\n[low]
#                                                    810
#                   NIST\r\n800-53\r\nrev5\r\n[moderate]
#                                                    666
#                       NIST\r\n800-53\r\nrev5\r\n[high]
#                                                    588
#                        NIST\r\n800-53\r\nrev5\r\n[NOC]
#                                                    639
#                   NIST\r\n800-63B\r\n[partial mapping]
#                                                   1001
#                                        NIST\r\n800-160
#                                                    961
#                          NIST \r\n800-161\r\n[partial]
#                                                    795
#                              NIST \r\n800-171\r\nrev 2
#                                                    838
#                                        NIST\r\n800-172
#                                                    910
#                                    NIST\r\nCSF\r\nv1.1
#                                                    887
#                               OWASP\r\nTop 10\r\nv2017
#                                                    889
#                                         PCIDSS\r\nv3.2
#                                                    834
#                                  SWIFT\r\nCSF\r\nv2019
#                                                    943
#                                           UL\r\n2900-1
#                                                    942
#                                 US CERT\r\nRMM\r\nv1.2
#                                                    716
#                         US\r\nCJIS Security Policy 5.9
#                                                    870
#                        US\r\nCMMC 2.0\r\nv1.02 Mapping
#                                                    857
#                              US\r\nCMMC 2.0\r\nLevel 1
#                                                    987
#                              US\r\nCMMC 2.0\r\nLevel 2
#                                                    945
#                              US\r\nCMMC 2.0\r\nLevel 3
#                                                    992
#                                            US\r\nCOPPA
#                                                   1000
#                           US\r\nDFARS\r\nCybersecurity
#                                                    993
#                                            US\r\nFACTA
#                                                   1004
#                                 US\r\nFAR\r\n52.204-21
#                                                    943
#                               US\r\nFAR\r\nSection 889
#                                                   1005
#                            US\r\nFDA\r\n21 CFR Part 11
#                                                    961
#                                          US\r\nFedRAMP
#                                                    577
#                                 US\r\nFedRAMP\r\n[low]
#                                                    859
#                            US\r\nFedRAMP\r\n[moderate]
#                                                    666
#                                US\r\nFedRAMP\r\n[high]
#                                                    578
#                             US\r\nFedRAMP\r\n[LI-SaaS]
#                                                    859
#                                            US\r\nFERPA
#                                                    990
#                                            US\r\nFFIEC
#                                                    935
#                                            US\r\nFINRA
#                                                   1002
#                                          US\r\nFTC Act
#                                                   1005
#                                             US\r\nGLBA
#                                                    998
#                                            US\r\nHIPAA
#                                                    930
#                         HIPAA - HICP\r\nSmall Practice
#                                                    925
#                        HIPAA - HICP\r\nMedium Practice
#                                                    870
#                         HIPAA - HICP\r\nLarge Practice
#                                                    774
#                                        US \r\nIRS 1075
#                                                    780
#                          ITAR\r\nPart 120\r\n[limited]
#                                                    983
#                                      US\r\nNERC\r\nCIP
#                                                    963
#                                           US\r\nNISPOM
#                                                    830
#                                   US\r\nPrivacy Shield
#                                                    993
#                                              US\r\nSOX
#                                                   1004
#                            US\r\nSSA \r\nEIESR\r\nv8.0
#                                                    900
#                         StateRAMP\r\nLow\r\nCategory 1
#                                                    887
#                        StateRAMP\r\nLow+\r\nCategory 2
#                                                    824
#                    StateRAMP\r\nModerate\r\nCategory 3
#                                                    701
#                                        US - AK\r\nPIPA
#                                                    988
#                                       US - CA\r\nSB327
#                                                   1000
#                                        US - CA\r\nCCPA
#                                                    921
#                                      US - CA\r\nSB1386
#                                                   1005
#                               US - MA\r\n201 CMR 17.00
#                                                    962
#                                       US - NV\r\nSB820
#                                                    999
#                          US - NY\r\nDFS\r\n23 NYCRR500
#                                                    981
#                                        US - OR\r\n646A
#                                                    965
#                 US - SC\r\nInsurance Data Security Act
#                                                    933
#                                       US - TX\r\nBC521
#                                                    994
#                             US-TX\r\nCybersecurity Act
#                                                    975
#                                         US-TX\r\nSB820
#                                                    999
#                                          US-VA\r\nCDPA
#                                                    976
#                               US-VT\r\nAct 171 of 2018
#                                                    950
#                         EMEA\r\nEU ePrivacy\r\n[draft]
#                                                    977
#                                     EMEA\r\nEU\r\nGDPR
#                                                    901
#                                     EMEA\r\nEU\r\nPSD2
#                                                    975
#                                        EMEA\r\nAustria
#                                                    947
#                                        EMEA\r\nBelgium
#                                                    951
#                                 EMEA\r\nCzech Republic
#                                                    976
#                                        EMEA\r\nDenmark
#                                                    983
#                                        EMEA\r\nFinland
#                                                    994
#                                         EMEA\r\nFrance
#                                                    982
#                                        EMEA\r\nGermany
#                                                    991
#                             EMEA\r\nGermany\r\nC5:2020
#                                                    768
#                                         EMEA\r\nGreece
#                                                    992
#                                        EMEA\r\nHungary
#                                                    982
#                                        EMEA\r\nIreland
#                                                    984
#                         EMEA\r\nIsrael\r\nCDMO\r\nv1.0
#                                                    612
#                                         EMEA\r\nIsrael
#                                                    987
#                                          EMEA\r\nItaly
#                                                    981
#                                     EMEA\r\nLuxembourg
#                                                    991
#                                    EMEA\r\nNetherlands
#                                                    982
#                                         EMEA\r\nNorway
#                                                    986
#                                         EMEA\r\nPoland
#                                                    980
#                                       EMEA\r\nPortugal
#                                                    983
#                                         EMEA\r\nRussia
#                                                    981
#                     EMEA\r\nSaudi Arabia\r\nECC-1 2018
#                                                    818
#                                EMEA\r\nSlovak Republic
#                                                   1004
#                                   EMEA\r\nSouth Africa
#                                                    909
#                                          EMEA\r\nSpain
#                                                    990
#                                         EMEA\r\nSweden
#                                                    984
#                                    EMEA\r\nSwitzerland
#                                                    993
#                                         EMEA\r\nTurkey
#                                                    991
#                                            EMEA\r\nUAE
#                                                    988
#                         EMEA\r\nUK\r\nCyber Essentials
#                                                    980
#                                      EMEA\r\nUK\r\nDPA
#                                                    996
#                                     EMEA\r\nUK\r\nGDPR
#                                                    957
#                                      APAC\r\nAustralia
#                                                    986
#                  APAC\r\nAustralian Privacy Principles
#                                                    981
#                          APAC\r\nAustralia\r\nISM 2020
#                                                    722
#              APAC\r\nAustralia\r\nIoT Code of Practice
#                                                    993
#               APAC\r\nChina\r\nData Security Law (DSL)
#                                                    991
#                                 APAC\r\nChina\r\nDNSIP
#                                                    999
#                           APAC\r\nChina\r\nPrivacy Law
#                                                    929
#                                      APAC\r\nHong Kong
#                                                    995
#                                   APAC\r\nIndia\r\nITR
#                                                    996
#                                      APAC\r\nIndonesia
#                                                    996
#                                          APAC\r\nJapan
#                                                    976
#                                       APAC\r\nMalaysia
#                                                    984
#                         APAC\r\nNew Zealand Health ISF
#                                                    979
#                       APAC\r\nNew Zealand\r\nNZISM 3.4
#                                                    749
#                APAC\r\nNew Zealand Privacy Act of 2020
#                                                    987
#                                    APAC\r\nPhilippines
#                                                    979
#                                      APAC\r\nSingapore
#                                                    979
#                           APAC\r\nSingapore MAS\r\nTRM
#                                                    843
#                                    APAC\r\nSouth Korea
#                                                    972
#                                         APAC\r\nTaiwan
#                                                    986
#                                  Americas\r\nArgentina
#                                                    979
#                  Americas\r\nArgentina\r\nReg 132/2018
#                                                    982
#                                    Americas\r\nBahamas
#                                                    991
#                         Americas\r\nBermuda\r\nBMA CCC
#                                                    948
#                             Americas\r\nBrazil\r\nLGPD
#                                                    976
#                             Americas\r\nCanada\r\nCSAG
#                                                    867
#                           Americas\r\nCanada\r\nPIPEDA
#                                                    981
#                                      Americas\r\nChile
#                                                    987
#                                   Americas\r\nColombia
#                                                    980
#                                 Americas\r\nCosta Rica
#                                                    992
#                                     Americas\r\nMexico
#                                                    986
#                                       Americas\r\nPeru
#                                                    990
#                                    Americas\r\nUruguay
#                                                    977
#            Minimum Security Requirements \r\nMCC + DSR
#                                                   1006
#          Identify\r\nMinimum Compliance Controls (MCC)
#                                                   1006
#  Identify\r\nDiscretionary Security Requirements (DSR)
#                                                   1006
#           SCF-B\r\n\r\nBusiness Mergers & Acquisitions
#                                                    516
#                    SCF-E\r\n\r\nEmbedded\r\nTechnology
#                                                    795
#                            SCF-G\r\n\r\nCMMC 2.0\r\nL2
#                                                    831
#                    SCF-H\r\n\r\nHealthcare\r\nIndustry
#                                                    873
#                  SCF-M\r\n\r\nContinuous\r\nMonitoring
#                                                    889
#                     SCF-P\r\n\r\nPrivacy\r\nManagement
#                                                    859
#                     SCF-R\r\n\r\nRansomware Protection
#                                                    490
#                       SCF-T\r\n\r\nThird-Party\r\nRisk
#                                                    623
#                                    Risk Threat Summary
#                                                      4
#                                         Risk\r\nR-AC-1
#                                                    405
#                                         Risk\r\nR-AC-2
#                                                    461
#                                         Risk\r\nR-AC-3
#                                                    465
#                                         Risk\r\nR-AC-4
#                                                    257
#                                         Risk\r\nR-AM-1
#                                                    350
#                                         Risk\r\nR-AM-2
#                                                    284
#                                         Risk\r\nR-BC-1
#                                                    212
#                                         Risk\r\nR-BC-2
#                                                    159
#                                         Risk\r\nR-BC-3
#                                                    270
#                                         Risk\r\nR-BC-4
#                                                    190
#                                         Risk\r\nR-BC-5
#                                                    324
#                                         Risk\r\nR-EX-1
#                                                    127
#                                         Risk\r\nR-EX-2
#                                                    136
#                                         Risk\r\nR-EX-3
#                                                    137
#                                         Risk\r\nR-EX-4
#                                                    127
#                                         Risk\r\nR-EX-5
#                                                    124
#                                         Risk\r\nR-EX-6
#                                                    341
#                                         Risk\r\nR-EX-7
#                                                    247
#                                         Risk\r\nR-GV-1
#                                                     47
#                                         Risk\r\nR-GV-2
#                                                    105
#                                         Risk\r\nR-GV-3
#                                                    333
#                                         Risk\r\nR-GV-4
#                                                     74
#                                         Risk\r\nR-GV-5
#                                                     99
#                                         Risk\r\nR-GV-6
#                                                    287
#                                         Risk\r\nR-GV-7
#                                                    291
#                                         Risk\r\nR-GV-8
#                                                    613
#                                         Risk\r\nR-IR-1
#                                                    250
#                                         Risk\r\nR-IR-2
#                                                    409
#                                         Risk\r\nR-IR-3
#                                                    361
#                                         Risk\r\nR-IR-4
#                                                    206
#                                         Risk\r\nR-SA-1
#                                                    287
#                                         Risk\r\nR-SA-2
#                                                    790
#                                 Control Threat Summary
#                                                      4
#                                         Threat\r\nNT-1
#                                                    876
#                                         Threat\r\nNT-2
#                                                    614
#                                         Threat\r\nNT-3
#                                                    614
#                                         Threat\r\nNT-4
#                                                    614
#                                         Threat\r\nNT-5
#                                                    614
#                                         Threat\r\nNT-6
#                                                    614
#                                         Threat\r\nNT-7
#                                                     14
#                                         Threat\r\nNT-8
#                                                    620
#                                         Threat\r\nNT-9
#                                                    625
#                                        Threat\r\nNT-10
#                                                    626
#                                        Threat\r\nNT-11
#                                                    614
#                                        Threat\r\nNT-12
#                                                    614
#                                        Threat\r\nNT-13
#                                                    614
#                                        Threat\r\nNT-14
#                                                    621
#                                         Threat\r\nMT-1
#                                                     10
#                                         Threat\r\nMT-2
#                                                     10
#                                         Threat\r\nMT-3
#                                                    611
#                                         Threat\r\nMT-4
#                                                    609
#                                         Threat\r\nMT-5
#                                                    588
#                                         Threat\r\nMT-6
#                                                    599
#                                         Threat\r\nMT-7
#                                                     30
#                                         Threat\r\nMT-8
#                                                      4
#                                         Threat\r\nMT-9
#                                                      1
#                                        Threat\r\nMT-10
#                                                    292
#                                   SCF Errata\r\n2021.1
#                                                    822
#                                   SCF Errata\r\n2021.2
#                                                    788
#                                   SCF Errata\r\n2021.3
#                                                    897
# [1] 1006  241
# Rows: 1,006
# Columns: 241
# $ `SCF Domain`                                             <chr> "Security & P…
# $ `SCF Control`                                            <chr> "Security & P…
# $ `SCF #`                                                  <chr> "GOV-01", "GO…
# $ `Secure Controls Framework (SCF)\r\nControl Description` <chr> "Mechanisms e…
# $ `Methods To Comply With SCF Controls`                    <chr> "- Steering c…
# $ `SCF Control Question`                                   <chr> "Does the org…
# $ `Function Grouping`                                      <chr> "Identify", "…
# $ `AICPA\r\nTSC 2017\r\n(SOC 2)`                           <chr> "CC1.2", NA, …
# $ `CIS\r\nCSC\r\nv7.1`                                     <chr> NA, NA, NA, N…
# $ `CIS\r\nCSC\r\nv8.0`                                     <chr> NA, NA, NA, N…
# $ `COBIT\r\n2019`                                          <chr> "EDM01.02\r\n…
# $ `COSO\r\nv2017`                                          <chr> "Principle 2"…
# $ `CSA\r\nCCM\r\nv3.0.1`                                   <chr> "GRM-04", NA,…
# $ `CSA\r\nCCM\r\nv4`                                       <chr> "GRC-05\r\nGR…
# $ `CSA\r\nIoT SCF\r\nv2`                                   <chr> "GVN-01\r\nGV…
# $ `ENISA\r\nv2.0`                                          <chr> NA, NA, "SO1"…
# $ GAPP                                                     <chr> "8.2.1", NA, …
# $ `IEC 62443-4-2`                                          <chr> NA, NA, NA, N…
# $ `ISO\r\n22301\r\nv2019`                                  <chr> "5.2\r\n5.2.1…
# $ `ISO\r\n27001\r\nv2013`                                  <chr> "4.3\r\n4.4\r…
# $ `ISO\r\n27002\r\nv2013`                                  <chr> "5.1.1", NA, …
# $ `ISO \r\n27018\r\nv2014`                                 <chr> NA, NA, NA, N…
# $ `ISO\r\n27701 \r\nv2019`                                 <chr> "5.3.1\r\n5.3…
# $ `ISO\r\n29100\r\nv2011`                                  <chr> "5.1\r\n5.10\…
# $ `ISO\r\n31000\r\nv2009`                                  <chr> NA, NA, NA, N…
# $ `ISO\r\n31010\r\nv2009`                                  <chr> NA, NA, NA, N…
# $ `MPA \r\nContent Security Program\r\nv4.07`              <chr> "MS-1.0\r\nMS…
# $ `NIAC\r\nInsurance Data Security Model Law (MDL-668)`    <chr> "Sec 4A\r\nSe…
# $ `NIST Privacy Framework\r\nv1.0`                         <chr> "GV.PO-P1\r\n…
# $ `NIST\r\nSSDF`                                           <chr> NA, NA, NA, N…
# $ `NIST\r\n800-37 \r\nrev 2`                               <chr> NA, NA, "P-5"…
# $ `NIST\r\n800-39`                                         <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev4`                                 <chr> "PM-1", NA, "…
# $ `NIST\r\n800-53 rev4\r\n[low]`                           <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53 rev4\r\n[moderate]`                      <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53 rev4\r\n[high]`                          <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev5`                                 <chr> "PM-1", NA, "…
# $ `NIST\r\n800-53\r\nrev5\r\n[privacy]`                    <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev5\r\n[low]`                        <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev5\r\n[moderate]`                   <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev5\r\n[high]`                       <chr> NA, NA, NA, N…
# $ `NIST\r\n800-53\r\nrev5\r\n[NOC]`                        <chr> "PM-1", NA, "…
# $ `NIST\r\n800-63B\r\n[partial mapping]`                   <chr> NA, NA, NA, N…
# $ `NIST\r\n800-160`                                        <chr> NA, NA, NA, N…
# $ `NIST \r\n800-161\r\n[partial]`                          <chr> "PM-1", NA, "…
# $ `NIST \r\n800-171\r\nrev 2`                              <chr> NA, NA, NA, N…
# $ `NIST\r\n800-172`                                        <chr> NA, NA, NA, N…
# $ `NIST\r\nCSF\r\nv1.1`                                    <chr> NA, NA, "ID.G…
# $ `OWASP\r\nTop 10\r\nv2017`                               <chr> NA, NA, NA, N…
# $ `PCIDSS\r\nv3.2`                                         <chr> "12.1\r\n12.1…
# $ `SWIFT\r\nCSF\r\nv2019`                                  <chr> NA, NA, NA, N…
# $ `UL\r\n2900-1`                                           <chr> NA, NA, NA, N…
# $ `US CERT\r\nRMM\r\nv1.2`                                 <chr> "EF:SG2.SP1\r…
# $ `US\r\nCJIS Security Policy 5.9`                         <chr> "5.1\r\n5.1.1…
# $ `US\r\nCMMC 2.0\r\nv1.02 Mapping`                        <chr> NA, NA, NA, N…
# $ `US\r\nCMMC 2.0\r\nLevel 1`                              <chr> NA, NA, NA, N…
# $ `US\r\nCMMC 2.0\r\nLevel 2`                              <chr> NA, NA, NA, N…
# $ `US\r\nCMMC 2.0\r\nLevel 3`                              <chr> NA, NA, NA, N…
# $ `US\r\nCOPPA`                                            <chr> NA, NA, NA, N…
# $ `US\r\nDFARS\r\nCybersecurity`                           <chr> "252.204-7008…
# $ `US\r\nFACTA`                                            <chr> NA, NA, NA, N…
# $ `US\r\nFAR\r\n52.204-21`                                 <chr> NA, NA, NA, N…
# $ `US\r\nFAR\r\nSection 889`                               <chr> NA, NA, NA, N…
# $ `US\r\nFDA\r\n21 CFR Part 11`                            <chr> NA, NA, "§ 11…
# $ `US\r\nFedRAMP`                                          <chr> NA, NA, NA, N…
# $ `US\r\nFedRAMP\r\n[low]`                                 <chr> NA, NA, NA, N…
# $ `US\r\nFedRAMP\r\n[moderate]`                            <chr> NA, NA, NA, N…
# $ `US\r\nFedRAMP\r\n[high]`                                <chr> NA, NA, NA, N…
# $ `US\r\nFedRAMP\r\n[LI-SaaS]`                             <chr> NA, NA, NA, N…
# $ `US\r\nFERPA`                                            <chr> "§ 1232h", NA…
# $ `US\r\nFFIEC`                                            <chr> NA, NA, "D1.G…
# $ `US\r\nFINRA`                                            <chr> "S-P (17 CFR …
# $ `US\r\nFTC Act`                                          <chr> NA, NA, NA, N…
# $ `US\r\nGLBA`                                             <chr> "6801(b)(1)",…
# $ `US\r\nHIPAA`                                            <chr> "164.306\r\n1…
# $ `HIPAA - HICP\r\nSmall Practice`                         <chr> "10.S.A", NA,…
# $ `HIPAA - HICP\r\nMedium Practice`                        <chr> "8.M.A", NA, …
# $ `HIPAA - HICP\r\nLarge Practice`                         <chr> "8.M.A\r\n10.…
# $ `US \r\nIRS 1075`                                        <chr> "9.3.18", NA,…
# $ `ITAR\r\nPart 120\r\n[limited]`                          <chr> NA, NA, NA, N…
# $ `US\r\nNERC\r\nCIP`                                      <chr> NA, NA, NA, "…
# $ `US\r\nNISPOM`                                           <chr> "8-100", NA, …
# $ `US\r\nPrivacy Shield`                                   <chr> NA, NA, NA, N…
# $ `US\r\nSOX`                                              <chr> NA, NA, NA, N…
# $ `US\r\nSSA \r\nEIESR\r\nv8.0`                            <chr> "5.0999999999…
# $ `StateRAMP\r\nLow\r\nCategory 1`                         <chr> NA, NA, NA, N…
# $ `StateRAMP\r\nLow+\r\nCategory 2`                        <chr> NA, NA, NA, N…
# $ `StateRAMP\r\nModerate\r\nCategory 3`                    <chr> NA, NA, NA, N…
# $ `US - AK\r\nPIPA`                                        <chr> "45.48.530", …
# $ `US - CA\r\nSB327`                                       <chr> NA, NA, NA, N…
# $ `US - CA\r\nCCPA`                                        <chr> "1798.81.5(b)…
# $ `US - CA\r\nSB1386`                                      <chr> NA, NA, NA, N…
# $ `US - MA\r\n201 CMR 17.00`                               <chr> "17.03(1)\r\n…
# $ `US - NV\r\nSB820`                                       <chr> NA, NA, NA, N…
# $ `US - NY\r\nDFS\r\n23 NYCRR500`                          <chr> "500.02", NA,…
# $ `US - OR\r\n646A`                                        <chr> NA, NA, NA, N…
# $ `US - SC\r\nInsurance Data Security Act`                 <chr> "38-99-20(A)"…
# $ `US - TX\r\nBC521`                                       <chr> "Sec. 521.052…
# $ `US-TX\r\nCybersecurity Act`                             <chr> "Sec 10", NA,…
# $ `US-TX\r\nSB820`                                         <chr> NA, NA, "Sec …
# $ `US-VA\r\nCDPA`                                          <chr> "59.1-574.A.3…
# $ `US-VT\r\nAct 171 of 2018`                               <chr> "§ 2447(a)\r\…
# $ `EMEA\r\nEU ePrivacy\r\n[draft]`                         <chr> NA, NA, NA, N…
# $ `EMEA\r\nEU\r\nGDPR`                                     <chr> "Art 32.1\r\n…
# $ `EMEA\r\nEU\r\nPSD2`                                     <chr> "Art 3", NA, …
# $ `EMEA\r\nAustria`                                        <chr> "Sec 14\r\nSe…
# $ `EMEA\r\nBelgium`                                        <chr> "Art 16", NA,…
# $ `EMEA\r\nCzech Republic`                                 <chr> "Art 13", NA,…
# $ `EMEA\r\nDenmark`                                        <chr> "Art 41", NA,…
# $ `EMEA\r\nFinland`                                        <chr> "Sec 5\r\nSec…
# $ `EMEA\r\nFrance`                                         <chr> "Art 34", NA,…
# $ `EMEA\r\nGermany`                                        <chr> "Sec 9\r\nSec…
# $ `EMEA\r\nGermany\r\nC5:2020`                             <chr> "OIS-01", NA,…
# $ `EMEA\r\nGreece`                                         <chr> "Art 10", NA,…
# $ `EMEA\r\nHungary`                                        <chr> "Sec 7", NA, …
# $ `EMEA\r\nIreland`                                        <chr> "Sec 2", NA, …
# $ `EMEA\r\nIsrael\r\nCDMO\r\nv1.0`                         <chr> "3.2\r\n4.25"…
# $ `EMEA\r\nIsrael`                                         <chr> "Sec 16\r\nSe…
# $ `EMEA\r\nItaly`                                          <chr> "Sec 31\r\nSe…
# $ `EMEA\r\nLuxembourg`                                     <chr> "Art 3\r\nArt…
# $ `EMEA\r\nNetherlands`                                    <chr> "Sec 12\r\nSe…
# $ `EMEA\r\nNorway`                                         <chr> "Sec 13\r\nSe…
# $ `EMEA\r\nPoland`                                         <chr> "Art 1\r\nArt…
# $ `EMEA\r\nPortugal`                                       <chr> "Art 14\r\nAr…
# $ `EMEA\r\nRussia`                                         <chr> "Art 7\r\nArt…
# $ `EMEA\r\nSaudi Arabia\r\nECC-1 2018`                     <chr> "1-2-1\r\n1-3…
# $ `EMEA\r\nSlovak Republic`                                <chr> NA, NA, NA, N…
# $ `EMEA\r\nSouth Africa`                                   <chr> "Sec 19\r\nSe…
# $ `EMEA\r\nSpain`                                          <chr> NA, NA, NA, N…
# $ `EMEA\r\nSweden`                                         <chr> "Sec 31", NA,…
# $ `EMEA\r\nSwitzerland`                                    <chr> "Art 7", NA, …
# $ `EMEA\r\nTurkey`                                         <chr> "Art 12", NA,…
# $ `EMEA\r\nUAE`                                            <chr> "Sec 15\r\nSe…
# $ `EMEA\r\nUK\r\nCyber Essentials`                         <chr> NA, NA, NA, N…
# $ `EMEA\r\nUK\r\nDPA`                                      <chr> NA, NA, NA, N…
# $ `EMEA\r\nUK\r\nGDPR`                                     <chr> NA, NA, NA, N…
# $ `APAC\r\nAustralia`                                      <chr> "APP Part 1\r…
# $ `APAC\r\nAustralian Privacy Principles`                  <chr> NA, NA, "APP …
# $ `APAC\r\nAustralia\r\nISM 2020`                          <chr> "0888", "0725…
# $ `APAC\r\nAustralia\r\nIoT Code of Practice`              <chr> NA, NA, NA, N…
# $ `APAC\r\nChina\r\nData Security Law (DSL)`               <chr> NA, NA, NA, N…
# $ `APAC\r\nChina\r\nDNSIP`                                 <chr> "Sec 4", NA, …
# $ `APAC\r\nChina\r\nPrivacy Law`                           <chr> "Article 58\r…
# $ `APAC\r\nHong Kong`                                      <chr> "Principle 4"…
# $ `APAC\r\nIndia\r\nITR`                                   <chr> "Sec 8", NA, …
# $ `APAC\r\nIndonesia`                                      <chr> "Art 9\r\nArt…
# $ `APAC\r\nJapan`                                          <chr> "Art 20", NA,…
# $ `APAC\r\nMalaysia`                                       <chr> "Sec 9", NA, …
# $ `APAC\r\nNew Zealand Health ISF`                         <chr> "3.1\r\n9.1",…
# $ `APAC\r\nNew Zealand\r\nNZISM 3.4`                       <chr> NA, "3.2.9.C.…
# $ `APAC\r\nNew Zealand Privacy Act of 2020`                <chr> NA, NA, NA, N…
# $ `APAC\r\nPhilippines`                                    <chr> "Sec 25\r\nSe…
# $ `APAC\r\nSingapore`                                      <chr> "Sec 12\r\nSe…
# $ `APAC\r\nSingapore MAS\r\nTRM`                           <chr> "3.2.2", NA, …
# $ `APAC\r\nSouth Korea`                                    <chr> "Art 3\r\nArt…
# $ `APAC\r\nTaiwan`                                         <chr> "Art 27", NA,…
# $ `Americas\r\nArgentina`                                  <chr> "Art 9\r\nArt…
# $ `Americas\r\nArgentina\r\nReg 132/2018`                  <chr> NA, NA, NA, N…
# $ `Americas\r\nBahamas`                                    <chr> "Sec 6", NA, …
# $ `Americas\r\nBermuda\r\nBMA CCC`                         <chr> "4\r\n5.4", "…
# $ `Americas\r\nBrazil\r\nLGPD`                             <chr> NA, NA, NA, N…
# $ `Americas\r\nCanada\r\nCSAG`                             <chr> "6.5\r\n6.6\r…
# $ `Americas\r\nCanada\r\nPIPEDA`                           <chr> "Principle 7"…
# $ `Americas\r\nChile`                                      <chr> "Art 7", NA, …
# $ `Americas\r\nColombia`                                   <chr> "Art 4", NA, …
# $ `Americas\r\nCosta Rica`                                 <chr> "Art 10", NA,…
# $ `Americas\r\nMexico`                                     <chr> "Art 19", NA,…
# $ `Americas\r\nPeru`                                       <chr> "Art 9\r\nArt…
# $ `Americas\r\nUruguay`                                    <chr> NA, NA, NA, N…
# $ `Minimum Security Requirements \r\nMCC + DSR`            <lgl> NA, NA, NA, N…
# $ `Identify\r\nMinimum Compliance Controls (MCC)`          <lgl> NA, NA, NA, N…
# $ `Identify\r\nDiscretionary Security Requirements (DSR)`  <lgl> NA, NA, NA, N…
# $ `SCF-B\r\n\r\nBusiness Mergers & Acquisitions`           <chr> "x", NA, "x",…
# $ `SCF-E\r\n\r\nEmbedded\r\nTechnology`                    <chr> "x", NA, NA, …
# $ `SCF-G\r\n\r\nCMMC 2.0\r\nL2`                            <chr> NA, NA, NA, N…
# $ `SCF-H\r\n\r\nHealthcare\r\nIndustry`                    <chr> "x", NA, "x",…
# $ `SCF-M\r\n\r\nContinuous\r\nMonitoring`                  <chr> NA, NA, NA, "…
# $ `SCF-P\r\n\r\nPrivacy\r\nManagement`                     <chr> "x", NA, "x",…
# $ `SCF-R\r\n\r\nRansomware Protection`                     <chr> NA, "x", "x",…
# $ `SCF-T\r\n\r\nThird-Party\r\nRisk`                       <chr> "x", NA, "x",…
# $ `Risk Threat Summary`                                    <chr> "R-AC-1\r\nR-…
# $ `Risk\r\nR-AC-1`                                         <chr> "R-AC-1", "R-…
# $ `Risk\r\nR-AC-2`                                         <chr> "R-AC-2", "R-…
# $ `Risk\r\nR-AC-3`                                         <chr> "R-AC-3", "R-…
# $ `Risk\r\nR-AC-4`                                         <chr> "R-AC-4", "R-…
# $ `Risk\r\nR-AM-1`                                         <chr> "R-AM-1", "R-…
# $ `Risk\r\nR-AM-2`                                         <chr> "R-AM-2", "R-…
# $ `Risk\r\nR-BC-1`                                         <chr> "R-BC-1", "R-…
# $ `Risk\r\nR-BC-2`                                         <chr> "R-BC-2", "R-…
# $ `Risk\r\nR-BC-3`                                         <chr> "R-BC-3", "R-…
# $ `Risk\r\nR-BC-4`                                         <chr> "R-BC-4", "R-…
# $ `Risk\r\nR-BC-5`                                         <chr> "R-BC-5", "R-…
# $ `Risk\r\nR-EX-1`                                         <chr> "R-EX-1", "R-…
# $ `Risk\r\nR-EX-2`                                         <chr> "R-EX-2", "R-…
# $ `Risk\r\nR-EX-3`                                         <chr> "R-EX-3", "R-…
# $ `Risk\r\nR-EX-4`                                         <chr> "R-EX-4", "R-…
# $ `Risk\r\nR-EX-5`                                         <chr> "R-EX-5", "R-…
# $ `Risk\r\nR-EX-6`                                         <chr> "R-EX-6", "R-…
# $ `Risk\r\nR-EX-7`                                         <chr> "R-EX-7", "R-…
# $ `Risk\r\nR-GV-1`                                         <chr> "R-GV-1", "R-…
# $ `Risk\r\nR-GV-2`                                         <chr> "R-GV-2", "R-…
# $ `Risk\r\nR-GV-3`                                         <chr> "R-GV-3", "R-…
# $ `Risk\r\nR-GV-4`                                         <chr> "R-GV-4", "R-…
# $ `Risk\r\nR-GV-5`                                         <chr> "R-GV-5", "R-…
# $ `Risk\r\nR-GV-6`                                         <chr> "R-GV-6", "R-…
# $ `Risk\r\nR-GV-7`                                         <chr> "R-GV-7", "R-…
# $ `Risk\r\nR-GV-8`                                         <chr> "R-GV-8", "R-…
# $ `Risk\r\nR-IR-1`                                         <chr> "R-IR-1", "R-…
# $ `Risk\r\nR-IR-2`                                         <chr> "R-IR-2", "R-…
# $ `Risk\r\nR-IR-3`                                         <chr> "R-IR-3", "R-…
# $ `Risk\r\nR-IR-4`                                         <chr> "R-IR-4", "R-…
# $ `Risk\r\nR-SA-1`                                         <chr> "R-SA-1", "R-…
# $ `Risk\r\nR-SA-2`                                         <chr> "R-SA-2", "R-…
# $ `Control Threat Summary`                                 <chr> "NT-7\r\nMT-1…
# $ `Threat\r\nNT-1`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-2`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-3`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-4`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-5`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-6`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-7`                                         <chr> "NT-7", "NT-7…
# $ `Threat\r\nNT-8`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-9`                                         <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-10`                                        <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-11`                                        <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-12`                                        <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-13`                                        <chr> NA, NA, NA, N…
# $ `Threat\r\nNT-14`                                        <chr> NA, NA, NA, N…
# $ `Threat\r\nMT-1`                                         <chr> "MT-1", "MT-1…
# $ `Threat\r\nMT-2`                                         <chr> "MT-2", "MT-2…
# $ `Threat\r\nMT-3`                                         <chr> NA, "MT-3", N…
# $ `Threat\r\nMT-4`                                         <chr> NA, "MT-4", N…
# $ `Threat\r\nMT-5`                                         <chr> NA, "MT-5", N…
# $ `Threat\r\nMT-6`                                         <chr> NA, "MT-6", N…
# $ `Threat\r\nMT-7`                                         <chr> "MT-7", "MT-7…
# $ `Threat\r\nMT-8`                                         <chr> "MT-8", "MT-8…
# $ `Threat\r\nMT-9`                                         <chr> "MT-9", "MT-9…
# $ `Threat\r\nMT-10`                                        <chr> NA, NA, NA, N…
# $ `SCF Errata\r\n2021.1`                                   <chr> "ISO 27001 6.…
# $ `SCF Errata\r\n2021.2`                                   <chr> NA, NA, NA, N…
# $ `SCF Errata\r\n2021.3`                                   <chr> "- ISO 27001 …

# %% [markdown]
# #### **Concatenation Tasks**

# %%
# Concatenate "Secure Controls Framework" column with “Methods To Comply With SCF Controls” and “SCF Control Question” columns into a new column
scf$"Control Objective Description" <- paste(scf$"Secure Controls Framework (SCF)\r\nControl Description", " ", scf$"Methods To Comply With SCF Controls", " ", 
scf$"SCF Control Question")

# Concatenate "SCF Control" and "SCF Number(#)" columns into a new column
scf$"Control Objective Name" <- paste(scf$"SCF Control", " ", scf$"SCF #")

# %%
# Drop "Secure Controls Framework", "SCF Control" and "SCF #" columns to match columns specified in specs doc
drop <- c("Secure Controls Framework (SCF)\r\nControl Description", "SCF Control", "SCF #")
scf_cleaned = scf[,!(names(scf) %in% drop)]

# %%
# Move "Control Objective Description" column to before "Methods to Comply" column
scf_cleaned <- scf_cleaned %>% 
  relocate("Control Objective Description", .before = "Methods To Comply With SCF Controls")

# Move "Control Objective Name" column to before "Methods to Comply" column
scf_cleaned <- scf_cleaned %>% 
  relocate("Control Objective Name", .before = "SCF Domain")

# %%
# Check first few rows again
head(scf_cleaned, 1)
# Out:
#   Control Objective Name                         SCF Domain
# 1 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
#   Control Objective Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Function Grouping AICPA\r\nTSC 2017\r\n(SOC 2) CIS\r\nCSC\r\nv7.1
# 1 Identify          CC1.2                        NA
#   CIS\r\nCSC\r\nv8.0 COBIT\r\n2019                                            ⋯
# 1 NA                 EDM01.02\r\nAPO01.09\r\nAPO04.01\r\nAPO13.01\r\nAPO13.02 ⋯
#   Threat\r\nMT-4 Threat\r\nMT-5 Threat\r\nMT-6 Threat\r\nMT-7 Threat\r\nMT-8
# 1 NA             NA             NA             MT-7           MT-8
#   Threat\r\nMT-9 Threat\r\nMT-10 SCF Errata\r\n2021.1 SCF Errata\r\n2021.2
# 1 MT-9           NA              ISO 27001 6.1.1      NA
#   SCF Errata\r\n2021.3
# 1 - ISO 27001 added 4.3 & 4.4

# %% [markdown]
# # **Transposing scf_cleaned Sheet**

# %%
# Transpose columns G thru IF from wide to long format into 2 columns called "regulation" and
# "chapterID" to map onto field called "Name" in Authority Document target table and 
# field called "Name" in Citation target table
# see https://tidyr.tidyverse.org/reference/pivot_longer.html
scf_cleaned_transposed <- scf_cleaned %>%
  pivot_longer(
    cols = "AICPA\r\nTSC 2017\r\n(SOC 2)":"SCF Errata\r\n2021.3",
    names_to = "regulation",
    values_to = "chapterID"
  )

# %%
# Check to see if transpose ran correctly for columns "regulation" and "chapterID"
select(scf_cleaned_transposed, regulation, chapterID, "Control Objective Name")
# Out:
#        regulation
# 1      AICPA\r\nTSC 2017\r\n(SOC 2)
# 2      CIS\r\nCSC\r\nv7.1
# 3      CIS\r\nCSC\r\nv8.0
# 4      COBIT\r\n2019
# 5      COSO\r\nv2017
# 6      CSA\r\nCCM\r\nv3.0.1
# 7      CSA\r\nCCM\r\nv4
# 8      CSA\r\nIoT SCF\r\nv2
# 9      ENISA\r\nv2.0
# 10     GAPP
# 11     IEC 62443-4-2
# 12     ISO\r\n22301\r\nv2019
# 13     ISO\r\n27001\r\nv2013
# 14     ISO\r\n27002\r\nv2013
# 15     ISO \r\n27018\r\nv2014
# 16     ISO\r\n27701 \r\nv2019
# 17     ISO\r\n29100\r\nv2011
# 18     ISO\r\n31000\r\nv2009
# 19     ISO\r\n31010\r\nv2009
# 20     MPA \r\nContent Security Program\r\nv4.07
# 21     NIAC\r\nInsurance Data Security Model Law (MDL-668)
# 22     NIST Privacy Framework\r\nv1.0
# 23     NIST\r\nSSDF
# 24     NIST\r\n800-37 \r\nrev 2
# 25     NIST\r\n800-39
# 26     NIST\r\n800-53\r\nrev4
# 27     NIST\r\n800-53 rev4\r\n[low]
# 28     NIST\r\n800-53 rev4\r\n[moderate]
# 29     NIST\r\n800-53 rev4\r\n[high]
# 30     NIST\r\n800-53\r\nrev5
# ⋮      ⋮
# 235375 Risk\r\nR-SA-1
# 235376 Risk\r\nR-SA-2
# 235377 Control Threat Summary
# 235378 Threat\r\nNT-1
# 235379 Threat\r\nNT-2
# 235380 Threat\r\nNT-3
# 235381 Threat\r\nNT-4
# 235382 Threat\r\nNT-5
# 235383 Threat\r\nNT-6
# 235384 Threat\r\nNT-7
# 235385 Threat\r\nNT-8
# 235386 Threat\r\nNT-9
# 235387 Threat\r\nNT-10
# 235388 Threat\r\nNT-11
# 235389 Threat\r\nNT-12
# 235390 Threat\r\nNT-13
# 235391 Threat\r\nNT-14
# 235392 Threat\r\nMT-1
# 235393 Threat\r\nMT-2
# 235394 Threat\r\nMT-3
# 235395 Threat\r\nMT-4
# 235396 Threat\r\nMT-5
# 235397 Threat\r\nMT-6
# 235398 Threat\r\nMT-7
# 235399 Threat\r\nMT-8
# 235400 Threat\r\nMT-9
# 235401 Threat\r\nMT-10
# 235402 SCF Errata\r\n2021.1
# 235403 SCF Errata\r\n2021.2
# 235404 SCF Errata\r\n2021.3
#        chapterID
# 1      CC1.2
# 2      NA
# 3      NA
# 4      EDM01.02\r\nAPO01.09\r\nAPO04.01\r\nAPO13.01\r\nAPO13.02
# 5      Principle 2
# 6      GRM-04
# 7      GRC-05\r\nGRC-07
# 8      GVN-01\r\nGVN-02
# 9      NA
# 10     8.2.1
# 11     NA
# 12     5.2\r\n5.2.1\r\n5.2.2
# 13     4.3\r\n4.4\r\n5.1\r\n6.1.1
# 14     5.1.1
# 15     NA
# 16     5.3.1\r\n5.3.2\r\n5.3.3\r\n5.4\r\n5.4.1\r\n5.4.1.1\r\n5.4.2\r\n5.5\r\n5.5.1\r\n5.5.2\r\n5.5.3\r\n5.5.4\r\n5.5.5\r\n5.5.5.1\r\n5.5.5.2\r\n5.5.5.3\r\n5.6.1\r\n5.6.2\r\n5.6.3\r\n5.7\r\n5.7.1\r\n5.7.2\r\n5.7.3\r\n5.8\r\n5.8.1\r\n5.8.1\r\n6.2\r\n6.2.1\r\n6.2.1.1\r\n6.5
# 17     5.1\r\n5.10\r\n5.11
# 18     NA
# 19     NA
# 20     MS-1.0\r\nMS-1.1\r\nMS-1.2\r\nMS-1.3
# 21     Sec 4A\r\nSec 4B\r\nSec 4E(1)\r\nSec 4G
# 22     GV.PO-P1\r\nGV.PO-P6
# 23     NA
# 24     NA
# 25     NA
# 26     PM-1
# 27     NA
# 28     NA
# 29     NA
# 30     PM-1
# ⋮      ⋮
# 235375 NA
# 235376 NA
# 235377 NT-7\r\nMT-1\r\nMT-2\r\nMT-7\r\nMT-8\r\nMT-9
# 235378 NA
# 235379 NA
# 235380 NA
# 235381 NA
# 235382 NA
# 235383 NA
# 235384 NT-7
# 235385 NA
# 235386 NA
# 235387 NA
# 235388 NA
# 235389 NA
# 235390 NA
# 235391 NA
# 235392 MT-1
# 235393 MT-2
# 235394 NA
# 235395 NA
# 235396 NA
# 235397 NA
# 235398 MT-7
# 235399 MT-8
# 235400 MT-9
# 235401 NA
# 235402 New addition
# 235403 NA
# 235404 NA
#        Control Objective Name
# 1      Security & Privacy Governance Program   GOV-01
# 2      Security & Privacy Governance Program   GOV-01
# 3      Security & Privacy Governance Program   GOV-01
# 4      Security & Privacy Governance Program   GOV-01
# 5      Security & Privacy Governance Program   GOV-01
# 6      Security & Privacy Governance Program   GOV-01
# 7      Security & Privacy Governance Program   GOV-01
# 8      Security & Privacy Governance Program   GOV-01
# 9      Security & Privacy Governance Program   GOV-01
# 10     Security & Privacy Governance Program   GOV-01
# 11     Security & Privacy Governance Program   GOV-01
# 12     Security & Privacy Governance Program   GOV-01
# 13     Security & Privacy Governance Program   GOV-01
# 14     Security & Privacy Governance Program   GOV-01
# 15     Security & Privacy Governance Program   GOV-01
# 16     Security & Privacy Governance Program   GOV-01
# 17     Security & Privacy Governance Program   GOV-01
# 18     Security & Privacy Governance Program   GOV-01
# 19     Security & Privacy Governance Program   GOV-01
# 20     Security & Privacy Governance Program   GOV-01
# 21     Security & Privacy Governance Program   GOV-01
# 22     Security & Privacy Governance Program   GOV-01
# 23     Security & Privacy Governance Program   GOV-01
# 24     Security & Privacy Governance Program   GOV-01
# 25     Security & Privacy Governance Program   GOV-01
# 26     Security & Privacy Governance Program   GOV-01
# 27     Security & Privacy Governance Program   GOV-01
# 28     Security & Privacy Governance Program   GOV-01
# 29     Security & Privacy Governance Program   GOV-01
# 30     Security & Privacy Governance Program   GOV-01
# ⋮      ⋮
# 235375 Web Browser Security   WEB-12
# 235376 Web Browser Security   WEB-12
# 235377 Web Browser Security   WEB-12
# 235378 Web Browser Security   WEB-12
# 235379 Web Browser Security   WEB-12
# 235380 Web Browser Security   WEB-12
# 235381 Web Browser Security   WEB-12
# 235382 Web Browser Security   WEB-12
# 235383 Web Browser Security   WEB-12
# 235384 Web Browser Security   WEB-12
# 235385 Web Browser Security   WEB-12
# 235386 Web Browser Security   WEB-12
# 235387 Web Browser Security   WEB-12
# 235388 Web Browser Security   WEB-12
# 235389 Web Browser Security   WEB-12
# 235390 Web Browser Security   WEB-12
# 235391 Web Browser Security   WEB-12
# 235392 Web Browser Security   WEB-12
# 235393 Web Browser Security   WEB-12
# 235394 Web Browser Security   WEB-12
# 235395 Web Browser Security   WEB-12
# 235396 Web Browser Security   WEB-12
# 235397 Web Browser Security   WEB-12
# 235398 Web Browser Security   WEB-12
# 235399 Web Browser Security   WEB-12
# 235400 Web Browser Security   WEB-12
# 235401 Web Browser Security   WEB-12
# 235402 Web Browser Security   WEB-12
# 235403 Web Browser Security   WEB-12
# 235404 Web Browser Security   WEB-12

# %% [markdown]
# # **Extracting Regulations and Removing Duplicates**

# %%
# Extracting regulations from the transposed df
source_auth_doc = scf_cleaned_transposed['regulation']
dim(source_auth_doc) #check dimension

# Removing duplicate regulations
source_auth_doc = source_auth_doc[!duplicated(source_auth_doc$regulation), ]

# Checking the df
head(source_auth_doc, 5)
dim(source_auth_doc)
# Out:
# [1] 235404      1
#   regulation
# 1 AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 CIS\r\nCSC\r\nv7.1
# 3 CIS\r\nCSC\r\nv8.0
# 4 COBIT\r\n2019
# 5 COSO\r\nv2017
# [1] 234   1

# %% [markdown]
# #**Extracting Citations and Removing Duplicates**

# %%
# Since some cells contain >1 chapter ID, separate such chapter IDs into separate rows
scf_cleaned_transposed_separate_chapterID = separate_rows(scf_cleaned_transposed,"chapterID", sep="\n")

# %%
# Check to make sure chapter IDs separated properly into individual rows
select(scf_cleaned_transposed_separate_chapterID, regulation, chapterID)
# Out:
#        regulation                   chapterID
# 1      AICPA\r\nTSC 2017\r\n(SOC 2) CC1.2
# 2      CIS\r\nCSC\r\nv7.1           NA
# 3      CIS\r\nCSC\r\nv8.0           NA
# 4      COBIT\r\n2019                EDM01.02\r
# 5      COBIT\r\n2019                APO01.09\r
# 6      COBIT\r\n2019                APO04.01\r
# 7      COBIT\r\n2019                APO13.01\r
# 8      COBIT\r\n2019                APO13.02
# 9      COSO\r\nv2017                Principle 2
# 10     CSA\r\nCCM\r\nv3.0.1         GRM-04
# 11     CSA\r\nCCM\r\nv4             GRC-05\r
# 12     CSA\r\nCCM\r\nv4             GRC-07
# 13     CSA\r\nIoT SCF\r\nv2         GVN-01\r
# 14     CSA\r\nIoT SCF\r\nv2         GVN-02
# 15     ENISA\r\nv2.0                NA
# 16     GAPP                         8.2.1
# 17     IEC 62443-4-2                NA
# 18     ISO\r\n22301\r\nv2019        5.2\r
# 19     ISO\r\n22301\r\nv2019        5.2.1\r
# 20     ISO\r\n22301\r\nv2019        5.2.2
# 21     ISO\r\n27001\r\nv2013        4.3\r
# 22     ISO\r\n27001\r\nv2013        4.4\r
# 23     ISO\r\n27001\r\nv2013        5.1\r
# 24     ISO\r\n27001\r\nv2013        6.1.1
# 25     ISO\r\n27002\r\nv2013        5.1.1
# 26     ISO \r\n27018\r\nv2014       NA
# 27     ISO\r\n27701 \r\nv2019       5.3.1\r
# 28     ISO\r\n27701 \r\nv2019       5.3.2\r
# 29     ISO\r\n27701 \r\nv2019       5.3.3\r
# 30     ISO\r\n27701 \r\nv2019       5.4\r
# ⋮      ⋮                            ⋮
# 282833 Control Threat Summary       MT-7\r
# 282834 Control Threat Summary       MT-8\r
# 282835 Control Threat Summary       MT-9
# 282836 Threat\r\nNT-1               NA
# 282837 Threat\r\nNT-2               NA
# 282838 Threat\r\nNT-3               NA
# 282839 Threat\r\nNT-4               NA
# 282840 Threat\r\nNT-5               NA
# 282841 Threat\r\nNT-6               NA
# 282842 Threat\r\nNT-7               NT-7
# 282843 Threat\r\nNT-8               NA
# 282844 Threat\r\nNT-9               NA
# 282845 Threat\r\nNT-10              NA
# 282846 Threat\r\nNT-11              NA
# 282847 Threat\r\nNT-12              NA
# 282848 Threat\r\nNT-13              NA
# 282849 Threat\r\nNT-14              NA
# 282850 Threat\r\nMT-1               MT-1
# 282851 Threat\r\nMT-2               MT-2
# 282852 Threat\r\nMT-3               NA
# 282853 Threat\r\nMT-4               NA
# 282854 Threat\r\nMT-5               NA
# 282855 Threat\r\nMT-6               NA
# 282856 Threat\r\nMT-7               MT-7
# 282857 Threat\r\nMT-8               MT-8
# 282858 Threat\r\nMT-9               MT-9
# 282859 Threat\r\nMT-10              NA
# 282860 SCF Errata\r\n2021.1         New addition
# 282861 SCF Errata\r\n2021.2         NA
# 282862 SCF Errata\r\n2021.3         NA

# %%
#keep only relevant columns for Control Objectives to Citations relationship table in SN
source_citation_to_control_objective = scf_cleaned_transposed_separate_chapterID[, c("Control Objective Name", "SCF Domain", "Control Objective Description", 
"Methods To Comply With SCF Controls", "SCF Control Question", "chapterID", "regulation")]

# %%
head(source_citation_to_control_objective, 5) #check the first few rows 
dim(source_citation_to_control_objective) #check the df dimension
# Out:
#   Control Objective Name                         SCF Domain
# 1 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 2 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 3 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 4 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 5 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
#   Control Objective Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 2 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 3 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 4 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 5 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   chapterID  regulation
# 1 CC1.2      AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 NA         CIS\r\nCSC\r\nv7.1
# 3 NA         CIS\r\nCSC\r\nv8.0
# 4 EDM01.02\r COBIT\r\n2019
# 5 APO01.09\r COBIT\r\n2019
# [1] 282862      7

# %%
#Remove duplicate PAIRS of regulations and chapter IDs
source_citation = source_citation_to_control_objective[!duplicated(source_citation_to_control_objective[c("chapterID","regulation")]),]

#Alternative method for removing duplicate PAIRS of regulations and chapter IDs 
#distinct(source_citation_to_control_objective, chapterID, regulation, .keep_all= TRUE)

head(source_citation, 5) #check the first few rows of new df
dim(source_citation) #check the new df dimension

#test removing duplicates on regulation, chapter ID, and control objective name columns
#source_test = source_citation_to_control_objective[!duplicated(source_citation_to_control_objective[c("chapterID","Control Objective Name", "regulation")]),]
#head(source_test, 5) #check the first few rows of new df
#dim(source_test) #check the new df dimension
# Out:
#   Control Objective Name                         SCF Domain
# 1 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 2 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 3 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 4 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 5 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
#   Control Objective Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 2 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 3 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 4 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 5 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   chapterID  regulation
# 1 CC1.2      AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 NA         CIS\r\nCSC\r\nv7.1
# 3 NA         CIS\r\nCSC\r\nv8.0
# 4 EDM01.02\r COBIT\r\n2019
# 5 APO01.09\r COBIT\r\n2019
# [1] 17838     7

# %% [markdown]
# #**Exporting cleaned data**

# %%
# Export cleaned scf sheet into new Excel file
write.xlsx(scf_cleaned, file = "/content/scf_auth_cleaned.xlsx", sheetName = "SCF 2021.3_cleaned", col.names = TRUE, row.names = TRUE, append = FALSE)

# Export cleaned scf sheet into new CSV file for Control Objectives table in SN
write.csv(scf_cleaned,"/content/scf_cleaned.csv", row.names = FALSE)

# %%
# Export regulations into new CSV file for Authority Docs table in SN
write.csv(source_auth_doc,"/content/regulations.csv", row.names = FALSE)

# %%
# Export citations into new CSV file for Citations table in SN
write.csv(source_citation,"/content/citations.csv", row.names = FALSE)

# %%
# Export Control Objectives to Citations into new CSV file for relationship table between 
# Control Objectives and Citations in SN
write.csv(source_citation_to_control_objective,"/content/citations_to_control_objectives.csv", row.names = FALSE)

# %%
# Export transposed data into new CSV file for reference
write.csv(scf_cleaned_transposed,"/content/scf_cleaned_transposed.csv", row.names = FALSE)

# %%
# Export cleaned authoritative sheet into separate new CSV file
# write.csv(auth_cleaned,"/content/auth_cleaned.csv", row.names = FALSE)

# %% [markdown]
# #**Cleaning SCF NEW sheet**

# %%
#Importing 2022 scf sheet
scf_new = read_excel("/content/SCF_current.xlsx")

# Checking first few rows of scf sheet
head(scf_new, n=1)

# Checking last few rows of scf sheet
tail(scf_new, n=1)

# Check dimensions
dim(scf_new)

# Check missing values
colSums(is.na(scf_new))

# Drop unnecesary columns from scf sheet
drop <- c("Relative Control\r\nWeighting\r\n(1-10)", "SCRM\r\nTier 1\r\nStrategic", "SCRM\r\nTier 2\r\nOperational", "SCRM\r\nTier 3\r\nTactical",
          "SP-CMM 0\r\nNot Performed", "SP-CMM 1\r\nPerformed Informally", "SP-CMM 2\r\nPlanned & Tracked", "SP-CMM 3\r\nWell Defined", 
          "SP-CMM 4\r\nQuantitatively Controlled", "SP-CMM 5\r\nContinuously Improving")
scf_new = scf_new[,!(names(scf_new) %in% drop)]

# Check df dimensions after dropping
dim(scf_new)

# Check datatypes of all columns again to make sure they match specs doc
glimpse(scf_new)

# %% [markdown]
# #### **Concatenation Tasks NEW**

# %%
# Concatenate "Secure Controls Framework" column with “Methods To Comply With SCF Controls” and “SCF Control Question” columns into a new column
scf_new$"Control Objective Description" <- paste(scf_new$"Secure Controls Framework (SCF)\r\nControl Description", " ", scf_new$"Methods To Comply With SCF Controls", " ", 
scf_new$"SCF Control Question")

# Concatenate "SCF Control" and "SCF Number(#)" columns into a new column
scf_new$"Control Objective Name" <- paste(scf_new$"SCF Control", " ", scf_new$"SCF #")

# Drop "Secure Controls Framework", "SCF Control" and "SCF #" columns to match columns specified in specs doc
drop <- c("Secure Controls Framework (SCF)\r\nControl Description", "SCF Control", "SCF #")
scf_new_cleaned = scf_new[,!(names(scf_new) %in% drop)] 

# Move "Control Objective Description" column to before "Methods to Comply" column
scf_new_cleaned <- scf_new_cleaned %>% 
  relocate("Control Objective Description", .before = "Methods To Comply With SCF Controls")

# Move "Control Objective Name" column to before "Methods to Comply" column
scf_new_cleaned <- scf_new_cleaned %>% 
  relocate("Control Objective Name", .before = "SCF Domain")

# Check first few rows again
head(scf_new_cleaned, 1)

# %% [markdown]
# # **Transposing scf_NEW_cleaned Sheet**

# %%
# Transpose columns G thru IF from wide to long format into 2 columns called "regulation" and
# "chapterID" to map onto field called "Name" in Authority Document target table and 
# field called "Name" in Citation target table
# see https://tidyr.tidyverse.org/reference/pivot_longer.html
scf_new_cleaned_transposed <- scf_new_cleaned %>%
  pivot_longer(
    cols = "AICPA\r\nTSC 2017\r\n(SOC 2)":"SCF Errata\r\n2022.1",
    names_to = "regulation",
    values_to = "chapterID"
  )

# Check to see if transpose ran correctly for columns "regulation" and "chapterID"
select(scf_new_cleaned_transposed, regulation, chapterID)

# %% [markdown]
# # **Extracting Regulations and Removing Duplicates NEW**

# %%
# Extracting regulations from the transposed df
source_auth_doc_new = scf_new_cleaned_transposed['regulation']
dim(source_auth_doc_new) #check dimension

# Removing duplicate regulations
source_auth_doc_new = source_auth_doc_new[!duplicated(source_auth_doc_new$regulation), ]

# Checking the df
head(source_auth_doc_new, 5)
dim(source_auth_doc_new)
# Out:
#   regulation
# 1 AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 CIS\r\nCSC\r\nv7.1
# 3 CIS\r\nCSC\r\nv8.0
# 4 COBIT\r\n2019
# 5 COSO\r\nv2017
# [1] 246   1

# %% [markdown]
# #**Extracting Citations and Removing Duplicates NEW**

# %%
# Since some cells contain >1 chapter ID, separate such chapter IDs into separate rows
scf_new_cleaned_transposed_separate_chapterID = separate_rows(scf_new_cleaned_transposed,"chapterID", sep="\n")

# %%
# Check to make sure chapter IDs separated properly into individual rows
select(scf_new_cleaned_transposed_separate_chapterID, regulation, chapterID)
# Out:
#        regulation                   chapterID
# 1      AICPA\r\nTSC 2017\r\n(SOC 2) CC1.2
# 2      CIS\r\nCSC\r\nv7.1           NA
# 3      CIS\r\nCSC\r\nv8.0           NA
# 4      COBIT\r\n2019                EDM01.02\r
# 5      COBIT\r\n2019                APO01.09\r
# 6      COBIT\r\n2019                APO04.01\r
# 7      COBIT\r\n2019                APO13.01\r
# 8      COBIT\r\n2019                APO13.02
# 9      COSO\r\nv2017                Principle 2
# 10     CSA\r\nCCM\r\nv3.0.1         GRM-04
# 11     CSA\r\nCCM\r\nv4             GRC-05\r
# 12     CSA\r\nCCM\r\nv4             GRC-07
# 13     CSA\r\nIoT SCF\r\nv2         GVN-01\r
# 14     CSA\r\nIoT SCF\r\nv2         GVN-02
# 15     ENISA\r\nv2.0                NA
# 16     GAPP                         8.2.1
# 17     IEC 62443-4-2                NA
# 18     ISO\r\n22301\r\nv2019        5.2\r
# 19     ISO\r\n22301\r\nv2019        5.2.1\r
# 20     ISO\r\n22301\r\nv2019        5.2.2
# 21     ISO\r\n27001\r\nv2013        4.3\r
# 22     ISO\r\n27001\r\nv2013        4.4\r
# 23     ISO\r\n27001\r\nv2013        5.1\r
# 24     ISO\r\n27001\r\nv2013        6.1.1
# 25     ISO\r\n27002\r\nv2013        5.1.1
# 26     ISO\r\n27002\r\nv2022        5.1\r
# 27     ISO\r\n27002\r\nv2022        5.4\r
# 28     ISO\r\n27002\r\nv2022        5.37
# 29     ISO \r\n27018\r\nv2014       NA
# 30     ISO\r\n27701 \r\nv2019       5.3.1\r
# ⋮      ⋮                            ⋮
# 300814 Control Threat Summary       MT-7\r
# 300815 Control Threat Summary       MT-8\r
# 300816 Control Threat Summary       MT-9\r
# 300817 Control Threat Summary       MT-11
# 300818 Threat\r\nNT-1               NA
# 300819 Threat\r\nNT-2               NA
# 300820 Threat\r\nNT-3               NA
# 300821 Threat\r\nNT-4               NA
# 300822 Threat\r\nNT-5               NA
# 300823 Threat\r\nNT-6               NA
# 300824 Threat\r\nNT-7               NT-7
# 300825 Threat\r\nNT-8               NA
# 300826 Threat\r\nNT-9               NA
# 300827 Threat\r\nNT-10              NA
# 300828 Threat\r\nNT-11              NA
# 300829 Threat\r\nNT-12              NA
# 300830 Threat\r\nNT-13              NA
# 300831 Threat\r\nNT-14              NA
# 300832 Threat\r\nMT-1               MT-1
# 300833 Threat\r\nMT-2               MT-2
# 300834 Threat\r\nMT-3               NA
# 300835 Threat\r\nMT-4               NA
# 300836 Threat\r\nMT-5               NA
# 300837 Threat\r\nMT-6               NA
# 300838 Threat\r\nMT-7               MT-7
# 300839 Threat\r\nMT-8               MT-8
# 300840 Threat\r\nMT-9               MT-9
# 300841 Threat\r\nMT-10              NA
# 300842 Threat\r\nMT-11              MT-11
# 300843 SCF Errata\r\n2022.1         NA

# %%
#keep only relevant columns for Control Objectives to Citations relationship table in SN
source_citation_to_control_objective_new = scf_new_cleaned_transposed_separate_chapterID[, c("Control Objective Name", "SCF Domain", "Control Objective Description", 
"Methods To Comply With SCF Controls", "SCF Control Question", "chapterID", "regulation")]

# %%
head(source_citation_to_control_objective_new, 5) #check the first few rows 
dim(source_citation_to_control_objective_new) #check the df dimension
# Out:
#   Control Objective Name                         SCF Domain
# 1 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 2 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 3 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 4 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 5 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
#   Control Objective Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 2 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 3 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 4 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 5 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   chapterID  regulation
# 1 CC1.2      AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 NA         CIS\r\nCSC\r\nv7.1
# 3 NA         CIS\r\nCSC\r\nv8.0
# 4 EDM01.02\r COBIT\r\n2019
# 5 APO01.09\r COBIT\r\n2019
# [1] 300843      7

# %%
#Remove duplicate PAIRS of regulations and chapter IDs
source_citation_new = source_citation_to_control_objective_new[!duplicated(source_citation_to_control_objective_new[c("chapterID","regulation")]),]

#Alternative method for removing duplicate PAIRS of regulations and chapter IDs 
#distinct(source_citation_to_control_objective, chapterID, regulation, .keep_all= TRUE)

head(source_citation_new, 5) #check the first few rows of new df
dim(source_citation_new) #check the new df dimension

#test removing duplicates on regulation, chapter ID, and control objective name columns
#source_test = source_citation_to_control_objective[!duplicated(source_citation_to_control_objective[c("chapterID","Control Objective Name", "regulation")]),]
#head(source_test, 5) #check the first few rows of new df
#dim(source_test) #check the new df dimension
# Out:
#   Control Objective Name                         SCF Domain
# 1 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 2 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 3 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 4 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
# 5 Security & Privacy Governance Program   GOV-01 Security & Privacy Governance
#   Control Objective Description
# 1 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Mechanisms exist to facilitate the implementation of cybersecurity and privacy governance controls.   - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)   Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   Methods To Comply With SCF Controls
# 1 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 2 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 3 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 4 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
# 5 - Steering committee\r\n- Digital Security Program (DSP)\r\n- Cybersecurity & Data Protection Program (CDPP)
#   SCF Control Question
# 1 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 2 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 3 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 4 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
# 5 Does the organization staff a function to centrally-govern cybersecurity and privacy controls?
#   chapterID  regulation
# 1 CC1.2      AICPA\r\nTSC 2017\r\n(SOC 2)
# 2 NA         CIS\r\nCSC\r\nv7.1
# 3 NA         CIS\r\nCSC\r\nv8.0
# 4 EDM01.02\r COBIT\r\n2019
# 5 APO01.09\r COBIT\r\n2019
# [1] 20990     7

# %% [markdown]
# #**Exporting cleaned data NEW**

# %%
# Export cleaned scf sheet into new CSV file for Control Objectives table in SN
write.csv(scf_new_cleaned,"/content/scf_new_cleaned.csv", row.names = FALSE)
# Out:
# Error in is.data.frame(x): object 'scf_new_cleaned' not found
# Traceback:
#
# 1. write.csv(scf_new_cleaned, "/content/scf_new_cleaned.csv", row.names = FALSE)
# 2. eval.parent(Call)
# 3. eval(expr, p)
# 4. eval(expr, p)
# 5. utils::write.table(scf_new_cleaned, "/content/scf_new_cleaned.csv",
#  .     row.names = FALSE, col.names = TRUE, sep = ",", dec = ".",
#  .     qmethod = "double")
# 6. is.data.frame(x)

# %%
# Export regulations into new CSV file for Authority Docs table in SN
write.csv(source_auth_doc_new,"/content/regulations_new.csv", row.names = FALSE)

# %%
# Export citations into new CSV file for Citations table in SN
write.csv(source_citation_new,"/content/citations_new.csv", row.names = FALSE)

# %%
# Export Control Objectives to Citations into new CSV file for relationship table between 
# Control Objectives and Citations in SN
write.csv(source_citation_to_control_objective_new,"/content/citations_to_control_objectives_new.csv", row.names = FALSE)

# %%
# Export transposed data into new CSV file for reference
write.csv(scf_new_cleaned_transposed,"/content/scf_new_cleaned_transposed.csv", row.names = FALSE)

# %%
# Export cleaned authoritative sheet into separate new CSV file
# write.csv(auth_cleaned,"/content/auth_cleaned.csv", row.names = FALSE)

# %% [markdown]
# # **Automate Regulatory Change Management**

# %%
dataframe1 = read.csv("/content/regulations.csv")
dataframe2 = read.csv("/content/regulations_new.csv")

dim(dataframe1)

dim(dataframe2)
# Out:
# [1] 234   1
# [1] 246   1

# %%
merge(dataframe1, dataframe2, by = 'regulation', type = "inner")
# Out:
#     regulation
# 1   AICPA\nTSC 2017\n(SOC 2)
# 2   Americas\nArgentina
# 3   Americas\nArgentina\nReg 132/2018
# 4   Americas\nBahamas
# 5   Americas\nBermuda\nBMA CCC
# 6   Americas\nBrazil\nLGPD
# 7   Americas\nCanada\nCSAG
# 8   Americas\nCanada\nPIPEDA
# 9   Americas\nChile
# 10  Americas\nColombia
# 11  Americas\nCosta Rica
# 12  Americas\nMexico
# 13  Americas\nPeru
# 14  Americas\nUruguay
# 15  APAC\nAustralia
# 16  APAC\nAustralia\nIoT Code of Practice
# 17  APAC\nAustralia\nISM 2020
# 18  APAC\nAustralian Privacy Principles
# 19  APAC\nChina\nData Security Law (DSL)
# 20  APAC\nChina\nDNSIP
# 21  APAC\nChina\nPrivacy Law
# 22  APAC\nHong Kong
# 23  APAC\nIndia\nITR
# 24  APAC\nIndonesia
# 25  APAC\nJapan
# 26  APAC\nMalaysia
# 27  APAC\nNew Zealand\nNZISM 3.4
# 28  APAC\nNew Zealand Health ISF
# 29  APAC\nNew Zealand Privacy Act of 2020
# 30  APAC\nPhilippines
# ⋮   ⋮
# 200 US\nFedRAMP\n[LI-SaaS]
# 201 US\nFedRAMP\n[low]
# 202 US\nFedRAMP\n[moderate]
# 203 US\nFERPA
# 204 US\nFFIEC
# 205 US\nFINRA
# 206 US\nFTC Act
# 207 US\nGLBA
# 208 US\nHIPAA
# 209 US\nNERC\nCIP
# 210 US\nNISPOM
# 211 US\nPrivacy Shield
# 212 US\nSOX
# 213 US\nSSA \nEIESR\nv8.0
# 214 US \nIRS 1075
# 215 US - AK\nPIPA
# 216 US - CA\nCCPA
# 217 US - CA\nSB1386
# 218 US - CA\nSB327
# 219 US - MA\n201 CMR 17.00
# 220 US - NV\nSB820
# 221 US - NY\nDFS\n23 NYCRR500
# 222 US - OR\n646A
# 223 US - SC\nInsurance Data Security Act
# 224 US - TX\nBC521
# 225 US CERT\nRMM\nv1.2
# 226 US-TX\nCybersecurity Act
# 227 US-TX\nSB820
# 228 US-VA\nCDPA
# 229 US-VT\nAct 171 of 2018

# %%
anti_join(dataframe2, dataframe1, by='regulation')
# Out:
#    regulation
# 1  ISO\n27002\nv2022
# 2  NIST \n800-171A
# 3  NIST\n800-218\nv1.1
# 4  Shared Assessments SIG 2022
# 5  US - CO\nColorado Privacy Act
# 6  US - IL\nPIPA
# 7  US - NY\nSHIELD Act\nS5575B
# 8  US-TX DIR Control Standards 2.0
# 9  US-TX\nTX-RAMP\nLevel 1
# 10 US-TX\nTX-RAMP\nLevel 2
# 11 EMEA\nSaudi Arabia\nSAAM CSF v1.0
# 12 APAC\nAustralia\nPrudential Standard CPS 234
# 13 APAC\nSingapore \nCyber Hygiene Practice
# 14 APAC\nSingapore MAS\nTRM 2021
# 15 SCF-G\n\nCMMC L3
# 16 Threat\nMT-11
# 17 SCF Errata\n2022.1
